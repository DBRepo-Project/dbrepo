# %%
import requests

service_url = 'http://localhost'
database_id = '443177e9-f125-469c-b687-203225a1f998'

username = "mweise"
password = "V0f38ad2!"

# %% [markdown]
# # Upload

# %% [markdown]
# # Analyse

# %% [markdown]
# # Import

# %% [markdown]
# # Query

# %%
payload = {
    "columns": [
        {
            "id": "e891ba86-0258-41a6-a8d9-ff58bc10b618",
            "alias": "string"
        }
    ],
    "joins": [
        {
            "type": "inner",
            "conditionals": [
                {
                    "column_id": "f7df2a7d-4ade-4c78-97b0-7c744d0893c7",
                    "foreign_column_id": "2eac80eb-f313-456c-b003-86855d53e080"
                }
            ],
            "datasource_id": "f7df2a7d-4ade-4c78-97b0-7c744d0893c7"
        }
    ],
    "filters": [
        {
            "type": "where",
            "value": "1",
            "column_id": "14128033-54b5-4818-a489-21b0dded86e2",
            "operator_id": "67c5b54d-2eb0-4f42-8dc1-a504562e9f32"
        }
    ],
    "orders": [
        {
            "direction": "asc",
            "column_id": "e891ba86-0258-41a6-a8d9-ff58bc10b618"
        }
    ],
    "datasource_ids": [
        "3fa85f64-5717-4562-b3fc-2c963f66afa6"
    ]
}
result = requests.post(f'{service_url}/api/v1/database/{database_id}/subset', auth=(username, password), json=payload)

# %% [markdown]
# # Export
